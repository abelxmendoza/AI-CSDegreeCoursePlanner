# %% [markdown]
# # Group 5 - Heuristics Search
# ## CPSC 481 Section 5 Fall 2023 Project 1
# ## Team Members:
# ## *   Divyansh Mohan Rao
# ## *   Ashfaqul Haque
# ## *   Cesar Gutierrez
# ## *   Abel Mendoza
# ## *   Richer Le
# ## *   Gerardo Robledo

# %% [markdown]
# **Project Instructions:**
#
#  https://docs.google.com/document/d/1tbmhsiJY3FAQbM218WFvwwsU85l7RHT_JLrVmKVxCEI/edit#heading=h.sf1rjk24v8by
#
#
# ---
#
#
# **Potential Github code to use:**
#
# https://github.com/aimacode/aima-python/blob/master/search4e.ipynb

# %% [markdown]
# # **Collecting Data**

# %% [markdown]
# Used the CSUF couse catalog and roadmap to create this dictionary of course info with pre req info

# %%
# Define course information using a dictionary this does not contain the GE, GR, And science electives placeholder
course_info = {
    "CPSC120": {
        "name": "Introduction to Programming",
        "units": 3,
        "difficulty": "1",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": []
    },
    "CPSC121": {
        "name": "Object-Oriented Programming",
        "units": 3,
        "difficulty": "1",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": ["CPSC120"]
    },
    "CPSC131": {
        "name": "Data Structures",
        "units": 3,
        "difficulty": "1",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": ["CPSC121"]
    },
    "CPSC223C": {
        "name": "C Programming",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC223J": {
        "name": "Java Programming",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC223N": {
        "name": "Visual C# Programming",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC223P": {
        "name": "Python Programming",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC223W": {
        "name": "Swift Programming",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC240": {
        "name": "Computer Organization and Assembly Language",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": ["CPSC131", "MATH170A"]
    },
    "CPSC253": {
        "name": "Cybersecurity Foundations and Principles",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": []
    },
    "CPSC315": {
        "name": "Professional Ethics in Computing",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC323": {
        "name": "Compilers and Languages",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC332": {
        "name": "File Structures and Database Systems",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC335": {
        "name": "Algorithfm Engineering",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC131","MATH170A", "MATH150A"]
    },
    "CPSC351": {
        "name": "Operating Systems Concepts",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC362": {
        "name": "Foundations of Software Engineering",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC471": {
        "name": "Computer Communications",
        "units": 3,
        "difficulty": "3",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC351"]
    },
    "CPSC481": {
        "name": "Artificial Intelligence",
        "units": 3,
        "difficulty": "3",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites":["CPSC335", "MATH338"]
    },
    "CPSC490": {
        "name": "Undergraduate Seminar in Computer Science",
        "units": 3,
        "difficulty": "3",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC362"]

    },
    "CPSC491": {
        "name": "Senior Capstone Project in Computer Science",
        "units": 3,
        "difficulty": "3",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC490"]
    },
    "MATH125": {
        "name": "Basic Calculus ",
        "units": 4,
        "difficulty": "1",
        "core_course": True,
        "category": "Mathematics Requirements",
        "prerequisites": []
    },
    "MATH150A": {
        "name": "Calculus I",
        "units": 4,
        "difficulty": "1",
        "core_course": True,
        "category": "Mathematics Requirements",
        "prerequisites": ["MATH125"]
    },
    "MATH150B": {
        "name": "Calculus II",
        "units": 4,
        "difficulty": "1",
        "core_course": True,
        "category": "Mathematics Requirements",
        "prerequisites": ["MATH150A"]
    },
    "MATH170A": {
        "name": "Mathematical Structures I",
        "units": 3,
        "difficulty": "1",
        "core_course": True,
        "category": "Mathematics Requirements",
        "prerequisites": []
    },
    "MATH170B": {
        "name": "Mathematical Structures II",
        "units": 3,
        "difficulty": "1",
        "core_course": True,
        "category": "Mathematics Requirements",
        "prerequisites": ["MATH170A"]
    },
    "MATH106": {
        "name": "Basic Statistics  ",
        "units": 4,
        "difficulty": "2",
        "core_course": True,
        "category": "Mathematics Requirements",
        "prerequisites": []
    },
    "MATH338": {
        "name": "Statistics Applied to Natural Sciences",
        "units": 4,
        "difficulty": "2",
        "core_course": True,
        "category": "Mathematics Requirements",
        "prerequisites": ["MATH106", "MATH150B"]
    },
    "CPSC254": {
        "name": "Software Development with Open Source Systems",
        "units": 3,
        "difficulty": "2",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131"]
    },
    "CPSC301": {
        "name": "Programming Lab Practicum",
        "units": 2,
        "difficulty": "2",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131"]
    },
    "CPSC349": {
        "name": "Web Front-End Engineering",
        "units": 3,
        "difficulty": "2",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131"]
    },
    "CPSC352": {
        "name": "Cryptography",
        "units": 3,
        "difficulty": "2",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["MATH170B", "CPSC131", "CPSC253"]
    },
    "CPSC375": {
        "name": "Introduction to Data Science and Big Data",
        "units": 3,
        "difficulty": "2",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131", "MATH338"]
    },
    "CPSC386": {
        "name": "Introduction to Game Design and Production",
        "units": 3,
        "difficulty": "2",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC121"]
    },
    "CPSC411": {
        "name": "Mobile Device Application Programming",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131"]
    },
    "CPSC411A": {
        "name": "Mobile Device Application Programming for Android",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131"]
    },
    "CPSC431": {
        "name": "Database and Applications",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC332"]
    },
    "CPSC439": {
        "name": "Theory of Computation",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC121","MATH170B"]
    },
    "CPSC440": {
        "name": "Computer System Architecture",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC240"]
    },
    "CPSC449": {
        "name": "Web Back-End Engineering",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC332"]
    },
    "CPSC454": {
        "name": "Cloud Computing and Security",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC351", "CPSC253"]
    },
    "CPSC455": {
        "name": "Web Security",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC351"]
    },
    "CPSC456": {
        "name": "Network Security Fundamentals",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC351"]
    },
    "CPSC458": {
        "name": "Malware Analysis",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC351"]
    },
    "CPSC459": {
        "name": "Blockchain Technologies",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC351", "CPSC352"]
    },
    "CPSC462": {
        "name": "Software Design",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC362"]
    },
    "CPSC463": {
        "name": "Software Testing",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC362"]
    },
    "CPSC464": {
        "name": "Software Architecture",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC362"]
    },
    "CPSC466": {
        "name": "Software Process",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC362"]
    },
    "CPSC474": {
        "name": "Parallel and Distributed Computing",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
         "prerequisites": ["CPSC351"]
    },
    "CPSC479": {
        "name": "Introduction to High-Performance Computing",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "prerequisites": ["CPSC351"]
    },
    "CPSC483": {
        "name": "Introduction to Machine Learning",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "prerequisites": ["CPSC335", "MATH338"]
    },
    "CPSC484": {
        "name": "Principles of Computer Graphics",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "prerequisites": ["CPSC131", "MATH150B", "MATH170B"]
    },
    "CPSC485": {
        "name": "Computational Bioinformatics",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "prerequisites": ["CPSC131"]
    },
    "CPSC486": {
        "name": "Game Programming",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "prerequisites": ["CPSC386", "CPSC484"]
    },
    "CPSC489": {
        "name": "Game Development Project",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "prerequisites": ["CPSC486"]
    },
    "CPSC499": {
        "name": "Independent Study",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "prerequisites": []
    },
    "EGGN495": {
        "name": "Professional Practice",
        "units": 2,
        "difficulty": "2",
        "core_course": False,
        "prerequisites": []
    }
}

# %% [markdown]
# We later added place holder courses for GE, GR and science elective to get the complete course info. We still had to keep the old course infor without the GE,GR science as first 3 trials use that

# %%
course_info_complete = {
    "CPSC120": {
        "name": "Introduction to Programming",
        "units": 3,
        "difficulty": "1",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": []
    },
    "CPSC121": {
        "name": "Object-Oriented Programming",
        "units": 3,
        "difficulty": "1",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": ["CPSC120"]
    },
    "CPSC131": {
        "name": "Data Structures",
        "units": 3,
        "difficulty": "1",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": ["CPSC121"]
    },
    "CPSC223C/J/N/P/W/": {
        "name": "C Programming",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC240": {
        "name": "Computer Organization and Assembly Language",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": ["CPSC131", "MATH170A"]
    },
    "CPSC253": {
        "name": "Cybersecurity Foundations and Principles",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Lower-Division Core",
        "prerequisites": []
    },
    "CPSC315": {
        "name": "Professional Ethics in Computing",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC323": {
        "name": "Compilers and Languages",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC332": {
        "name": "File Structures and Database Systems",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC335": {
        "name": "Algorithfm Engineering",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC131","MATH170A", "MATH150A"]
    },
    "CPSC351": {
        "name": "Operating Systems Concepts",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC362": {
        "name": "Foundations of Software Engineering",
        "units": 3,
        "difficulty": "2",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC131"]
    },
    "CPSC471": {
        "name": "Computer Communications",
        "units": 3,
        "difficulty": "3",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC351"]
    },
    "CPSC481": {
        "name": "Artificial Intelligence",
        "units": 3,
        "difficulty": "3",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites":["CPSC335", "MATH338"]
    },
    "CPSC490": {
        "name": "Undergraduate Seminar in Computer Science",
        "units": 3,
        "difficulty": "3",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC362"]

    },
    "CPSC491": {
        "name": "Senior Capstone Project in Computer Science",
        "units": 3,
        "difficulty": "3",
        "core_course": True,
        "category": "Upper-Division Core",
        "prerequisites": ["CPSC490"]
    },
    "MATH125": {
        "name": "Basic Calculus ",
        "units": 4,
        "difficulty": "1",
        "core_course": True,
        "category": "Mathematics Requirements",
        "prerequisites": []
    },
    "MATH150A": {
        "name": "Calculus I",
        "units": 4,
        "difficulty": "1",
        "core_course": True,
        "category": "Mathematics Requirements",
        "prerequisites": ["MATH125"]
    },
    "MATH150B": {
        "name": "Calculus II",
        "units": 4,
        "difficulty": "1",
        "core_course": True,
        "category": "Mathematics Requirements",
        "prerequisites": ["MATH150A"]
    },
    "MATH170A": {
        "name": "Mathematical Structures I",
        "units": 3,
        "difficulty": "1",
        "core_course": True,
        "category": "Mathematics Requirements",
        "prerequisites": []
    },
    "MATH170B": {
        "name": "Mathematical Structures II",
        "units": 3,
        "difficulty": "1",
        "core_course": True,
        "category": "Mathematics Requirements",
        "prerequisites": ["MATH170A"]
    },
    # "MATH106": {
    #     "name": "Basic Statistics  ",
    #     "units": 4,
    #     "difficulty": "2",
    #     "core_course": True,
    #     "category": "Mathematics Requirements",
    #     "prerequisites": []
    # },
    "MATH338": {
        "name": "Statistics Applied to Natural Sciences",
        "units": 4,
        "difficulty": "2",
        "core_course": True,
        "category": "Mathematics Requirements",
        "prerequisites": [ "MATH150B"]
    },
    "CPSC254": {
        "name": "Software Development with Open Source Systems",
        "units": 3,
        "difficulty": "2",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131"]
    },
    "CPSC301": {
        "name": "Programming Lab Practicum",
        "units": 2,
        "difficulty": "2",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131"]
    },
    "CPSC349": {
        "name": "Web Front-End Engineering",
        "units": 3,
        "difficulty": "2",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131"]
    },
    "CPSC352": {
        "name": "Cryptography",
        "units": 3,
        "difficulty": "2",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["MATH170B", "CPSC131", "CPSC253"]
    },
    "CPSC375": {
        "name": "Introduction to Data Science and Big Data",
        "units": 3,
        "difficulty": "2",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131", "MATH338"]
    },
    "CPSC386": {
        "name": "Introduction to Game Design and Production",
        "units": 3,
        "difficulty": "2",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC121"]
    },
    "CPSC411": {
        "name": "Mobile Device Application Programming",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131"]
    },
    "CPSC411A": {
        "name": "Mobile Device Application Programming for Android",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131"]
    },
    "CPSC431": {
        "name": "Database and Applications",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC332"]
    },
    "CPSC439": {
        "name": "Theory of Computation",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC121","MATH170B"]
    },
    "CPSC440": {
        "name": "Computer System Architecture",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC240"]
    },
    "CPSC449": {
        "name": "Web Back-End Engineering",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC332"]
    },
    "CPSC454": {
        "name": "Cloud Computing and Security",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC351", "CPSC253"]
    },
    "CPSC455": {
        "name": "Web Security",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC351"]
    },
    "CPSC456": {
        "name": "Network Security Fundamentals",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC351"]
    },
    "CPSC458": {
        "name": "Malware Analysis",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC351"]
    },
    "CPSC459": {
        "name": "Blockchain Technologies",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC351", "CPSC352"]
    },
    "CPSC462": {
        "name": "Software Design",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC362"]
    },
    "CPSC463": {
        "name": "Software Testing",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC362"]
    },
    "CPSC464": {
        "name": "Software Architecture",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC362"]
    },
    "CPSC466": {
        "name": "Software Process",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC362"]
    },
    "CPSC474": {
        "name": "Parallel and Distributed Computing",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
         "prerequisites": ["CPSC351"]
    },
    "CPSC479": {
        "name": "Introduction to High-Performance Computing",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC351"]
    },
    "CPSC483": {
        "name": "Introduction to Machine Learning",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC335", "MATH338"]
    },
    "CPSC484": {
        "name": "Principles of Computer Graphics",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131", "MATH150B", "MATH170B"]
    },
    "CPSC485": {
        "name": "Computational Bioinformatics",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC131"]
    },
    "CPSC486": {
        "name": "Game Programming",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC386", "CPSC484"]
    },
    "CPSC489": {
        "name": "Game Development Project",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": ["CPSC486"]
    },
    "CPSC499": {
        "name": "Independent Study",
        "units": 3,
        "difficulty": "3",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": []
    },
    "EGGN495": {
        "name": "Professional Practice",
        "units": 2,
        "difficulty": "2",
        "core_course": False,
        "category": "Computer Science Electives",
        "prerequisites": []
    },
    "GE1": {
        "name": "GE1 Placeholder",
        "units": 3,
        "difficulty": "1",
        "core_course": False,
         "category": "GE Requirement",
        "prerequisites": []
    },
    "GE2": {
        "name": "GE2 Placeholder",
        "units": 3,
        "difficulty": "1",
        "core_course": False,
        "category": "GE Requirement",
        "prerequisites": []
    },
    "GE3": {
        "name": "GE3 Placeholder",
        "units": 3,
        "difficulty": "1",
        "core_course": False,
        "category": "GE Requirement",
        "prerequisites": []
    },
    "GE4": {
        "name": "GE4 Placeholder",
        "units": 3,
        "difficulty": "1",
        "core_course": False,
        "category": "GE Requirement",
        "prerequisites": []
    },
    "GE5": {
        "name": "GE5 Placeholder",
        "units": 3,
        "difficulty": "1",
        "core_course": False,
        "category": "GE Requirement",
        "prerequisites": []
    },
    "GE6": {
        "name": "GE6 Placeholder",
        "units": 3,
        "difficulty": "1",
        "core_course": False,
        "category": "GE Requirement",
        "prerequisites": []
    },
    "GE7": {
        "name": "GE7 Placeholder",
        "units": 3,
        "difficulty": "1",
        "core_course": False,
        "category": "GE Requirement",
        "prerequisites": []
    },
    "GE8": {
        "name": "GE8 Placeholder",
        "units": 3,
        "difficulty": "1",
        "core_course": False,
        "category": "GE Requirement",
        "prerequisites": []
    },
    "GE9": {
        "name": "GE9 Placeholder",
        "units": 4,
        "difficulty": "1",
        "core_course": False,
        "category": "GE Requirement",
        "prerequisites": []
    },
    "GE10": {
        "name": "GE10 Placeholder",
        "units": 4,
        "difficulty": "1",
        "core_course": False,
        "category": "GE Requirement",
        "prerequisites": []
    },
    "GE11": {
        "name": "GE11 Placeholder",
        "units": 2,
        "difficulty": "1",
        "core_course": False,
        "category": "GE Requirement",
        "prerequisites": []
    },
    "GE12": {
        "name": "GE12 Placeholder",
        "units": 2,
        "difficulty": "1",
        "core_course": False,
        "category": "GE Requirement",
        "prerequisites": []
    },

    "GR1": {
        "name": "GR1 Placeholder",
        "units": 3,
        "difficulty": "1",
        "core_course": False,
        "category": "GR Requirement",
        "prerequisites": []
    },
    "Science1": {
        "name": "Science1 Placeholder",
        "units": 4,
        "difficulty": "1",
        "core_course": False,
        "category": "Science Elective",
        "prerequisites": []
    },
    "Science2": {
        "name": "Science2 Placeholder",
        "units": 4,
        "difficulty": "1",
        "core_course": False,
        "category": "Science Elective",
        "prerequisites": []
    },
    "Science3": {
        "name": "Science3 Placeholder",
        "units": 4,
        "difficulty": "1",
        "core_course": False,
        "category": "Science Elective",
        "prerequisites": []
    },
    "Science4": {
        "name": "Science3 Placeholder",
        "units": 3,
        "difficulty": "1",
        "core_course": False,
        "category": "Science Elective",
        "prerequisites": []
    },
    "Science5": {
        "name": "Science3 Placeholder",
        "units": 2,
        "difficulty": "1",
        "core_course": False,
        "category": "Science Elective",
        "prerequisites": []
    },
}

# %% [markdown]
# # **Formulating the Problem Defintion**

# %% [markdown]
# ### Formal Definition
#
# **Initial State:** A list of completed courses.
#
# **Goal State:** A plan that covers all required courses for graduation, with no more than 17 units per semester.
#
# **State Space:**
# ![WhatsApp Image 2023-09-30 at 12.34.43 AM.jpeg](data:image/jpeg;base64,...)
#
#
#
#
# **Actions:** Each action will add a set of courses to the current semester's plan, subject to the maximum academic load constraint and prerequisite requirements.
#
#
# ```
# Action 1: ['CPSC301'] (based on prerequisites and academic load)
# Action 2: ['CPSC411'] (based on prerequisites and academic load)
# Action 3: ['CPSC223']
# ```
#
#
# **Transition Model:** Given the current state (course plan), the transition model generates the next state (course plan for the next semester) by considering prerequisites, the maximum academic load.
#
#
#
# ```
# Assuming courses were empty in Semester 1 and CS120 is selected, the transition model updates the state to: ['CS120']
# ```
#
#
#
# **Cost Function:**
#
#
#
# ```
# path cost for each semester as 1
# ```

# %% [markdown]
# ### Starter Code from AIMA repository
#
# This code has been taken as is from the [AIMA Repo](https://github.com/aimacode/aima-python/blob/master/search4e.ipynb)

# %%
import matplotlib.pyplot as plt
import random
import heapq
import math
import sys
from collections import defaultdict, deque, Counter
from itertools import combinations


class Problem(object):
    """The abstract class for a formal problem. A new domain subclasses this,
    overriding `actions` and `results`, and perhaps other methods.
    The default heuristic is 0 and the default action cost is 1 for all states.
    When yiou create an instance of a subclass, specify `initial`, and `goal` states
    (or give an `is_goal` method) and perhaps other keyword args for the subclass."""

    def __init__(self, initial=None, goal=None, **kwds):
        self.__dict__.update(initial=initial, goal=goal, **kwds)

    def actions(self, state):        raise NotImplementedError
    def result(self, state, action): raise NotImplementedError
    def is_goal(self, state):        return state == self.goal
    def action_cost(self, s, a, s1): return 1
    def h(self, node):               return 0

    def __str__(self):
        return '{}({!r}, {!r})'.format(
            type(self).__name__, self.initial, self.goal)


class Node:
    "A Node in a search tree."
    def __init__(self, state, parent=None, action=None, path_cost=0):
        self.__dict__.update(state=state, parent=parent, action=action, path_cost=path_cost)

    def __repr__(self): return '<{}>'.format(self.state)
    def __len__(self): return 0 if self.parent is None else (1 + len(self.parent))
    def __lt__(self, other): return self.path_cost < other.path_cost


failure = Node('failure', path_cost=math.inf) # Indicates an algorithm couldn't find a solution.
cutoff  = Node('cutoff',  path_cost=math.inf) # Indicates iterative deepening search was cut off.

FIFOQueue = deque

LIFOQueue = list

class PriorityQueue:
    """A queue in which the item with minimum f(item) is always popped first."""

    def __init__(self, items=(), key=lambda x: x):
        self.key = key
        self.items = [] # a heap of (score, item) pairs
        for item in items:
            self.add(item)

    def add(self, item):
        """Add item to the queuez."""
        pair = (self.key(item), item)
        heapq.heappush(self.items, pair)

    def pop(self):
        """Pop and return the item with min f(item) value."""
        return heapq.heappop(self.items)[1]

    def top(self): return self.items[0][1]

    def __len__(self): return len(self.items)

def expand(problem, node):
    "Expand a node, generating the children nodes."
    s = node.state
    for action in problem.actions(s):
        s1 = problem.result(s, action)
        cost = node.path_cost + problem.action_cost(s, action, s1)
        yield Node(s1, node, action, cost)


def path_actions(node):
    "The sequence of actions to get to this node."
    if node.parent is None:
        return []
    return path_actions(node.parent) + [node.action]


def path_states(node):
    "The sequence of states to get to this node."
    if node in (cutoff, failure, None):
        return []
    return path_states(node.parent) + [node.state]


def best_first_search(problem, f):
    "Search nodes with minimum f(node) value first."
    node = Node(problem.initial)
    frontier = PriorityQueue([node], key=f)
    reached = {problem.initial: node}
    while frontier:
        node = frontier.pop()
        if problem.is_goal(node.state):
            return node
        for child in expand(problem, node):
            s = child.state
            if s not in reached or child.path_cost < reached[s].path_cost:
                reached[s] = child
                frontier.add(child)
    return failure

def breadth_first_search(problem):
    "Search shallowest nodes in the search tree first."
    node = Node(problem.initial)
    if problem.is_goal(problem.initial):
        return node
    frontier = FIFOQueue([node])
    reached = {problem.initial}
    while frontier:
        node = frontier.pop()
        for child in expand(problem, node):
            s = child.state
            if problem.is_goal(s):
                return child
            if s not in reached:
                reached.add(s)
                frontier.appendleft(child)
    return failure

def g(n): return n.path_cost

def is_cycle(node, k=30):
    "Does this node form a cycle of length k or less?"
    def find_cycle(ancestor, k):
        return (ancestor is not None and k > 0 and
                (ancestor.state == node.state or find_cycle(ancestor.parent, k - 1)))
    return find_cycle(node.parent, k)

def best_first_tree_search(problem, f):
    "A version of best_first_search without the `reached` table."
    frontier = PriorityQueue([Node(problem.initial)], key=f)
    while frontier:
        node = frontier.pop()
        # print("Node",node)
        if problem.is_goal(node.state):
            return node
        for child in expand(problem, node):
            # print("child",child)
            if not is_cycle(child):
                frontier.add(child)
    return failure

def astar_tree_search(problem, h=None):
    """Search nodes with minimum f(n) = g(n) + h(n), with no `reached` table."""
    h = h or problem.h
    return best_first_tree_search(problem, f=lambda n: g(n) + h(n))

def astar_search(problem, h=None):
    """Search nodes with minimum f(n) = g(n) + h(n)."""
    h = h or problem.h
    return best_first_search(problem, f=lambda n: g(n) + h(n))

def depth_first_bfs(problem):
    "Search deepest nodes in the search tree first; using best-first."
    return best_first_tree_search(problem, f=lambda n: -len(n))
def depth_limited_search(problem, limit=10):
    "Search deepest nodes in the search tree first."
    frontier = LIFOQueue([Node(problem.initial)])
    result = failure
    while frontier:
        node = frontier.pop()
        if problem.is_goal(node.state):
            return node
        elif len(node) >= limit:
            result = cutoff
        elif not is_cycle(node):
            for child in expand(problem, node):
                frontier.append(child)
    return result


def depth_first_recursive_search(problem, node=None):
    if node is None:
        node = Node(problem.initial)
    if problem.is_goal(node.state):
        return node
    elif is_cycle(node):
        return failure
    else:
        for child in expand(problem, node):
            result = depth_first_recursive_search(problem, child)
            if result:
                return result
        return failure

# %% [markdown]
# ### Problem Formulation according to AIMA model
#
# Basic skeleton defintion of the problem

# %%
class CoursePlanProblem(Problem):
    """
    Problem about creating a semester-by-semester course plan for Computer Science program.
    Each state represents the current course plan, and the goal is to satisfy graduation requirements.
    """



    def actions(self, state):
        """The actions executable in this state."""
        # Implement the actions to add courses to the current semester
        # The actions should consider prerequisites and the maximum academic load constraint
        pass

    def result(self, state, action):
        """The state that results from executing this action in this state."""
        # Implement how the state is modified based on the chosen action
        pass

    def is_goal(self, state):

        # Check if the requirment for each category has been fulfillied
        pass

# %% [markdown]
# ### Defining Heuristics

# %%
# give value based on courses with status as not_complete
# worked initially but failed to give optimal output becuase we donot need to complete all the courses to graduate
def min_remaining_units_heuristic(node):
    remaining_units = sum(course_info[course]["units"] for course, status in node.state.items() if status == "not_completed")
    return remaining_units


# More Robust Heuristic this check for reamining_units which tells how many units per category is left
def min_remaining_units_heuristic_per_category(node):
  remaining_unit = node.state.get('remaining_units',{})
  total_rem = 0
  for category, units in remaining_unit.items():
    if units >= 0:
      total_rem+=units
  # print("min rem",total_rem)
  return total_rem

# %% [markdown]
# ### Trail 1
# - Defined the actions to only take one valid action per state and used a class variable to monitor currently inprogess units(which was a bad idea)
# - Does not take care of unit limitation properly, also only sets one valid task per node
# - We were keeping track of the inprogress units in class variable which was not giving expected value at each node

# %%
import math
from collections import defaultdict

class CoursePlanProblemTrail1(Problem):
    def __init__(self, initial, course_info, max_units_per_semester, course_categories):
        self.initial = initial
        self.course_info = course_info
        self.max_units_per_semester = max_units_per_semester
        self.course_categories = course_categories
        self.remaining_units = {category: requirement for category, requirement in course_categories.items()}
        self.current_semester_units = 0
        self.currently_inprogress_units = 0
        self.currentSem  = 0
        self.semesterPlan = {}
        super().__init__(initial, None)

    def actions(self, state):
      available_courses = [course for course, status in state.items() if status != 'completed']
      valid_actions = []
      current_units_in_progress = sum(self.course_info[course]['units'] for course, status in state.items() if status == 'in_progress')
      courses_to_complete = []

      for course in available_courses:
          if self.can_take_course(course, state):
              units_added = self.course_info[course]['units']
              if current_units_in_progress + units_added > self.max_units_per_semester:
                  courses_to_complete.append(course)
              else:
                  valid_actions.append(('Take', course))
      if courses_to_complete:
          valid_actions.append(('Complete', courses_to_complete))
      if len(valid_actions) > 0:
          return [valid_actions[0]]
      else:
        return [('Complete', [course for course, status in state.items() if status == 'in_progress'])]
      return []

    def result(self, state, action):
        new_state = dict(state)
        action_type, course = action

        if action_type == 'Take':
            course_units = self.course_info[course].get('units', 0)
            new_state[course] = 'in_progress'
            self.currently_inprogress_units += course_units

        elif action_type == 'Complete':
            for cor in course:
              new_state[cor] = 'completed'
              self.update_remaining_units(cor, new_state)
        return new_state

    def is_goal(self, state):
      completed_units = {category: 0 for category in self.course_categories}
      for course, status in state.items():
        if status == 'completed' and course in self.course_info:
            category = self.course_info[course].get('category')
            units = self.course_info[course].get('units', 0)
            if category in completed_units:
                completed_units[category] += units
      for category, unit_requirement in self.course_categories.items():
        if completed_units[category] < unit_requirement:
            return False  # The goal is not achieved

      return True

    def h(self, state):
        return sum(max(0, unit_requirement) for unit_requirement in self.remaining_units.values())

    def can_take_course(self, course, state):
      prerequisites = self.course_info[course].get('prerequisites', [])

      prerequisites_met = all(state[prereq] == 'completed' for prereq in prerequisites)
      return prerequisites_met and state[course] != "in_progress"

    def update_remaining_units(self, course, state):
        category = self.course_info[course].get('category')
        units = self.course_info[course].get('units', 0)
        if category in self.remaining_units:
            self.remaining_units[category] = max(0, self.remaining_units[category] - units)

# %% [markdown]
# ### Trail 2
# - At each state an action will take as many courses that have prereq met and is under the max units allowed per sem
# - Treating each node of tree as a semester where we take as many course as we can

# %%
import math
from collections import defaultdict

class CoursePlanProblemTrail2(Problem):
    def __init__(self, initial, course_info, max_units_per_semester, course_categories, current_sem = 1):
        self.initial = initial
        self.initial["remaining_units"] = {category: requirement for category, requirement in course_categories.items()}
        self.initial["currently_inprogress_units"] = 0
        # self.initial["current_semester"] = current_sem
        self.course_info = course_info
        self.max_units_per_semester = max_units_per_semester
        self.course_categories = course_categories
        self.remaining_units = {category: requirement for category, requirement in course_categories.items()}
        self.current_semester_units = 0
        self.currently_inprogress_units = 0
        self.currentSem  = 0
        self.semesterPlan = {}
        super().__init__(initial, None)

    def actions(self, state):
      available_courses = [course for course, status in state.items() if status not in ['completed', "in_progress"]]
      valid_actions = []
      current_units_in_progress = 0
      courses_to_complete = []
      courses_to_take = []

      for course in available_courses:
          if self.can_take_course(course, state):
              units_added = self.course_info[course]['units']
              if current_units_in_progress + units_added < self.max_units_per_semester:
                  courses_to_take.append(course)
                  current_units_in_progress += units_added
      if len(courses_to_take) > 0:
          valid_actions.append(('Take', courses_to_take))
      return valid_actions


    def result(self, state, action):
        new_state = dict(state)
        action_type, courses = action
        # print("action",action)
        if action_type == 'Take':
            for course in courses:
              course_units = self.course_info[course].get('units', 0)
              new_state[course] = 'in_progress'
              self.currently_inprogress_units += course_units
        elif action_type == 'Complete':
            for cor in course:

              new_state[cor] = 'completed'
              self.update_remaining_units(cor, new_state)
        return new_state

    def is_goal(self, state):
      completed_units = {category: 0 for category in self.course_categories}
      for course, status in state.items():
        if status == 'completed' or status == "in_progress" and course in self.course_info:
            category = self.course_info[course].get('category')
            units = self.course_info[course].get('units', 0)
            if category in completed_units:
                completed_units[category] += units
      for category, unit_requirement in self.course_categories.items():
        if completed_units[category] < unit_requirement:
            return False  # The goal is not achieved

      return True

    def h(self, state):
        return sum(max(0, unit_requirement) for unit_requirement in self.remaining_units.values())

    def can_take_course(self, course, state):
      if(course in ["remaining_units", "currently_inprogress_units"]):
        return False
      prerequisites = self.course_info[course].get('prerequisites', [])
      prerequisites_met = all(state[prereq] in ['completed', 'in_progress'] for prereq in prerequisites)
      return prerequisites_met and state[course] not in ["in_progress", "completed"]


    def can_complete_course(self, course, state):
        return state[course] == 'in_progress'

    def update_remaining_units(self, course, state):
        category = self.course_info[course].get('category')
        units = self.course_info[course].get('units', 0)
        if category in self.remaining_units:
            self.remaining_units[category] = max(0, self.remaining_units[category] - units)

# %% [markdown]
# ### Trail 3
# - Treating each course as node of the tree
# - created new properties in state to keep track of inprogess units and current_semester
# - Does not take GE, GR into consideration

# %%
import math
from collections import defaultdict

class CoursePlanProblemTrail3(Problem):
    def __init__(self, initial, course_info, max_units_per_semester, course_categories, current_sem = 1):
        self.initial = initial
        # self.initial["remaining_units"] = {category: requirement for category, requirement in course_categories.items()}
        self.initial["currently_inprogress_units"] = 0
        self.initial["current_semester"] = current_sem
        self.course_info = course_info
        self.max_units_per_semester = max_units_per_semester
        self.course_categories = course_categories
        self.remaining_units = {category: requirement for category, requirement in course_categories.items()}
        self.current_semester_units = 0
        self.currently_inprogress_units = 0
        self.currentSem  = 0
        self.semesterPlan = {}
        super().__init__(initial, None)

    def actions(self, state):
      available_courses = [course for course, status in state.items() if status not in ['completed', "in_progress"]]
      valid_actions = []
      current_units_in_progress = state['currently_inprogress_units']
      courses_to_complete = []
      courses_to_take = []

      for course in available_courses:
          if self.can_take_course(course, state):
              units_added = self.course_info[course]['units']
              if current_units_in_progress + units_added < self.max_units_per_semester:
                  valid_actions.append(('Take', course))
                  current_units_in_progress += units_added

      if(len(valid_actions) == 0 and any(status == 'in_progress' for status in state.values()) ):

         valid_actions.append(('Complete', 'Semester: ' + str(state['current_semester'])))
      return valid_actions


    def result(self, state, action):
        new_state = dict(state)
        action_type, course = action
        # print("action",action)
        if action_type == 'Take':

            course_units = self.course_info[course].get('units', 0)
            new_state[course] = 'in_progress'
            new_state['currently_inprogress_units'] += course_units
            self.currently_inprogress_units += course_units

        elif action_type == 'Complete':
            for course in new_state:
              if new_state[course] == 'in_progress':
                new_state[course] = 'completed'
            new_state['current_semester'] +=1
            new_state['currently_inprogress_units'] = 0
        return new_state

    def is_goal(self, state):
      completed_units = {category: 0 for category in self.course_categories}
      for course, status in state.items():
        if status == 'completed' or status == "in_progress" and course in self.course_info:
            category = self.course_info[course].get('category')
            units = self.course_info[course].get('units', 0)
            if category in completed_units:
                completed_units[category] += units
      for category, unit_requirement in self.course_categories.items():
        if completed_units[category] < unit_requirement:
            return False  # The goal is not achieved

      return True

    def h(self, state):
        return sum(max(0, unit_requirement) for unit_requirement in self.remaining_units.values())

    def can_take_course(self, course, state):
      if(course in ["remaining_units", "currently_inprogress_units", "current_semester"]):
        return False
      prerequisites = self.course_info[course].get('prerequisites', [])

      prerequisites_met = all(state[prereq] in ['completed'] for prereq in prerequisites)
      return prerequisites_met and state[course] not in ["completed", 'in_progress']



    def can_complete_course(self, course, state):
        return state[course] == 'in_progress'

    def update_remaining_units(self, course, state):
        category = self.course_info[course].get('category')
        units = self.course_info[course].get('units', 0)
        if category in self.remaining_units:
            self.remaining_units[category] = max(0, self.remaining_units[category] - units)

# %% [markdown]
# ### Trail 4 with GE,GR and Science
# - Takes GE, GR and Science into planning
# - Takes 9 semester to complete
# - using a heuristic funtion that calculates number of courses in state 'not_completed' at each state

# %%
import math
from collections import defaultdict


class CoursePlanProblemTrail4(Problem):
    def __init__(self, initial, course_info, max_units_per_semester, course_categories, current_sem = 1):
        self.initial = initial
        self.initial["remaining_units"] = {category: requirement for category, requirement in course_categories.items()}
        self.initial["currently_inprogress_units"] = 0
        self.initial["current_semester"] = current_sem
        self.course_info = course_info
        self.max_units_per_semester = max_units_per_semester
        self.course_categories = course_categories
        self.remaining_units = {category: requirement for category, requirement in course_categories.items()}
        self.current_semester_units = 0
        self.currently_inprogress_units = 0
        self.currentSem  = 0
        self.semesterPlan = {}
        super().__init__(initial, None)

    def actions(self, state):
      available_courses = [course for course, status in state.items() if status not in ['completed', "in_progress"]]
      valid_actions = []
      current_units_in_progress = state['currently_inprogress_units']
      courses_to_complete = []
      courses_to_take = []

      for course in available_courses:
          if self.can_take_course(course, state,True):
              units_added = self.course_info[course]['units']
              if current_units_in_progress + units_added <= self.max_units_per_semester:
                  valid_actions.append(('Take', course))
                  current_units_in_progress += units_added
      if len(valid_actions) == 0:
        for course in available_courses:
          if self.can_take_course(course, state,False):
              units_added = self.course_info[course]['units']
              if current_units_in_progress + units_added <= self.max_units_per_semester:
                  valid_actions.append(('Take', course))
                  current_units_in_progress += units_added
      if(len(valid_actions) == 0 and any(status == 'in_progress' for status in state.values()) ):

         valid_actions.append(('Complete', 'Semester: ' + str(state['current_semester'])))
      return valid_actions

    def result(self, state, action):
        new_state = dict(state)
        action_type, course = action
        if action_type == 'Take':

            course_units = self.course_info[course].get('units', 0)
            couse_category = self.course_info[course].get('category')
            new_state[course] = 'in_progress'
            new_state['currently_inprogress_units'] += course_units
            self.currently_inprogress_units += course_units

        elif action_type == 'Complete':
            for course in new_state:
              # print("new_state",course)
              if new_state[course] == 'in_progress':
                new_state[course] = 'completed'
                course_units = self.course_info[course].get('units', 0)
                couse_category = self.course_info[course].get('category')
                new_state['remaining_units'][couse_category] -= course_units
            new_state['current_semester'] +=1
            new_state['currently_inprogress_units'] = 0
        return new_state

    def is_goal(self, state):
      completed_units = {category: 0 for category in self.course_categories}
      for course, status in state.items():
        if status == 'completed' or status == "in_progress" and course in self.course_info:
            category = self.course_info[course].get('category')
            units = self.course_info[course].get('units', 0)
            if category in completed_units:
                completed_units[category] += units
      for category, unit_requirement in self.course_categories.items():
        if completed_units[category] < unit_requirement:
            return False  # The goal is not achieved

      return True

    def h(self, state):
        return sum(max(0, unit_requirement) for unit_requirement in self.remaining_units.values())

    def can_take_course(self, course, state, checkUnits):
      if(course in ["remaining_units", "currently_inprogress_units", "current_semester"]):
        return False
      prerequisites = self.course_info[course].get('prerequisites', [])


      Category = self.course_info[course].get('category')
      units = self.course_info[course].get('units',0)
      prerequisites_met = all(state[prereq] in ['completed'] for prereq in prerequisites)
      is_course_prereq = False
      if checkUnits:
        return prerequisites_met and state[course] not in ["completed", 'in_progress'] and  (state['remaining_units'].get(Category) >= units )
      return prerequisites_met and state[course] not in ["completed", 'in_progress']



    def can_complete_course(self, course, state):
        return state[course] == 'in_progress'

    def update_remaining_units(self, course, state):
        category = self.course_info[course].get('category')
        units = self.course_info[course].get('units', 0)
        if category in self.remaining_units:
            self.remaining_units[category] = max(0, self.remaining_units[category] - units)

# %% [markdown]
# ### Solution
# - Completes in 8 semester
# - Uses a heuristic function that calculates 'Remaining units' for each 'category' that is needed to graduate
# - Updated the definition of goal state to check for state property to determine if the Goal is reached

# %%
import math
from collections import defaultdict

class CoursePlanProblem(Problem):
    def __init__(self, initial, course_info, max_units_per_semester, course_categories, current_sem = 1, preference_list = []):
        self.initial = initial
        self.initial["remaining_units"] = {category: requirement for category, requirement in course_categories.items()}
        self.initial["currently_inprogress_units"] = 0
        self.initial["current_semester"] = current_sem
        self.course_info = course_info
        self.max_units_per_semester = max_units_per_semester
        self.course_categories = course_categories
        self.remaining_units = {category: requirement for category, requirement in course_categories.items()}
        self.current_semester_units = 0
        self.currently_inprogress_units = 0
        self.currentSem  = 0
        self.preference_list = preference_list
        super().__init__(initial, None)

    def actions(self, state):
      available_courses = [course for course, status in state.items() if status not in ['completed', 'in_progress'] and course not in ["remaining_units", "currently_inprogress_units", "current_semester"]]
      valid_actions = []
      current_units_in_progress = state['currently_inprogress_units']
      courses_to_complete = []
      courses_to_take = []


      course_weight = {course: 0 for course in available_courses}
      total_remaining = sum(total for total in state['remaining_units'].values())
      for course in available_courses:
          course_units = self.course_info[course].get('units',0)
          course_weight[course]  = total_remaining - course_units
          if course in self.preference_list:
            course_weight[course] -= course_units
      sorted_courses = sorted(available_courses, key=lambda course: course_weight[course], reverse=False)


      for course in sorted_courses:
          if self.can_take_course(course, state, True):
              units_added = self.course_info[course]['units']
              if current_units_in_progress + units_added <= self.max_units_per_semester:
                  valid_actions.append(('Take', course))
                  current_units_in_progress += units_added

      if len(valid_actions) == 0:
          for course in sorted_courses:
              if self.can_take_course(course, state, False):
                  units_added = self.course_info[course]['units']
                  if current_units_in_progress + units_added <= self.max_units_per_semester:
                      valid_actions.append(('Take', course))
                      current_units_in_progress += units_added

      if len(valid_actions) == 0 and any(status == 'in_progress' for status in state.values()):
          valid_actions.append(('Complete', 'Semester: ' + str(state['current_semester'])))
      return valid_actions


    def result(self, state, action):
        new_state = dict(state)
        action_type, course = action
        # print("action",action)
        # print("restlt state",new_state)
        if action_type == 'Take':

            course_units = self.course_info[course].get('units', 0)
            couse_category = self.course_info[course].get('category')
            new_state[course] = 'in_progress'
            new_state['currently_inprogress_units'] += course_units
            self.currently_inprogress_units += course_units

        elif action_type == 'Complete':
            for course in new_state:
              # print("new_state",course)
              if new_state[course] == 'in_progress':
                new_state[course] = 'completed'
                course_units = self.course_info[course].get('units', 0)
                couse_category = self.course_info[course].get('category')
                new_state['remaining_units'][couse_category] -= course_units
            new_state['current_semester'] +=1
            new_state['currently_inprogress_units'] = 0
        return new_state

    def is_goal(self, state):
      for category, units in state['remaining_units'].items():
        if units > 0:
          return False
      return True

    def h(self, state):
        return sum(max(0, unit_requirement) for unit_requirement in self.remaining_units.values())

    def can_take_course(self, course, state, checkUnits):
      # print(course)
      if(course in ["remaining_units", "currently_inprogress_units", "current_semester"]):
        return False
      prerequisites = self.course_info[course].get('prerequisites', [])


      Category = self.course_info[course].get('category')
      units = self.course_info[course].get('units',0)

      prerequisites_met = all(state[prereq] in ['completed'] for prereq in prerequisites)
      is_course_prereq = False

      if checkUnits:
        return prerequisites_met and state[course] not in ["completed", 'in_progress'] and  (state['remaining_units'].get(Category) >= units )
      return prerequisites_met and state[course] not in ["completed", 'in_progress']

    def can_complete_course(self, course, state):
        return state[course] == 'in_progress'

    def update_remaining_units(self, course, state):
        category = self.course_info[course].get('category')
        units = self.course_info[course].get('units', 0)
        if category in self.remaining_units:
            self.remaining_units[category] = max(0, self.remaining_units[category] - units)

# %% [markdown]
# # Demonstrating Results

# %% [markdown]
# ## Output: Student starting Fresh

# %% [markdown]
# ### First Try (Output for CoursePlanProblemTrail1 Problem Definition)

# %%
max_units_per_semester = 17
initial_state = {course: 'not_completed' for course in course_info}
course_categories = {
    'Upper-Division Core': 30,
    'Lower-Division Core': 18,
    'Mathematics Requirements': 18,
    'Computer Science Electives': 15
}
problemTrail1 = CoursePlanProblemTrail1(initial_state, course_info, max_units_per_semester, course_categories)
result = astar_tree_search(problemTrail1,min_remaining_units_heuristic)

if result != failure and result != cutoff:
    i = 1
    units_for_this_semester = 0
    print("\nCourse Plan:")
    for action, course in zip(path_actions(result), path_states(result)[1:]):
        if action[0] == 'Take':
            print("\nSemester: " + str(i))
            print(f"Action: {action} " + str(course_info[action[1]].get("name")))
            units_for_this_semester += course_info[action[1]].get("units")
            print("Total units so far: " + str(units_for_this_semester))
            if units_for_this_semester > 15:
                units_for_this_semester = 0
        elif action[0] == 'Complete':
            units_for_this_semester = 0
            print("\nBy the end of the semester: " + str(i))
            i += 1
            for cors in action[1]:
                print(f"{action[0]} " + f"{cors} " + str(course_info[cors].get("name")))
        #print(f"\nCourse Status: {course}")
else:
    print("\nNo valid course plan found.")
# Out:
# Course Plan:
#
# Semester: 1
# Action: ('Take', 'CPSC120') Introduction to Programming
# Total units so far: 3
#
# Semester: 1
# Action: ('Take', 'CPSC253') Cybersecurity Foundations and Principles
# Total units so far: 6
#
# Semester: 1
# Action: ('Take', 'MATH125') Basic Calculus
# Total units so far: 10
#
# Semester: 1
# Action: ('Take', 'MATH170A') Mathematical Structures I
# Total units so far: 13
#
# Semester: 1
# Action: ('Take', 'MATH106') Basic Statistics
# Total units so far: 17
#
# By the end of the semester: 1
# Complete CPSC499 Independent Study
# Complete EGGN495 Professional Practice
#
# By the end of the semester: 2
# Complete CPSC120 Introduction to Programming
# Complete CPSC253 Cybersecurity Foundations and Principles
# Complete MATH125 Basic Calculus
# Complete MATH170A Mathematical Structures I
# Complete MATH106 Basic Statistics
#
# Semester: 3
# Action: ('Take', 'CPSC121') Object-Oriented Programming
# Total units so far: 3
#
# Semester: 3
# ...

# %% [markdown]
# Takes more number of courses than allowed

# %% [markdown]
# ### Second Try (Output for  CoursePlanProblemTrail2 Problem Definition)

# %%
max_units_per_semester = 17
initial_state = {course: 'not_completed' for course in course_info}
course_categories = {
    'Upper-Division Core': 30,
    'Lower-Division Core': 18,
    'Mathematics Requirements': 18,
    'Computer Science Electives': 15
}

# Find a course plan using A* search

problemTrail2 = CoursePlanProblemTrail2(initial_state, course_info, max_units_per_semester, course_categories)
result = astar_tree_search(problemTrail2,min_remaining_units_heuristic)

if result != failure and result != cutoff:
    print("Course Plan:")
    for action, course in zip(path_actions(result), path_states(result)[1:]):
        print(f"Action: {action}, Course: {course}")
else:
    print("No valid course plan found.")
# Out:
# Course Plan:
# ...

# %% [markdown]
# Taking as many available courses per semester limits the search space

# %% [markdown]
# ### Third Try (Output for  CoursePlanProblemTrail3 Problem Definition)

# %%
max_units_per_semester = 17
initial_state = {course: 'not_completed' for course in course_info}
course_categories = {
    'Upper-Division Core': 30,
    'Lower-Division Core': 18,
    'Mathematics Requirements': 18,
    'Computer Science Electives': 15
}

# Find a course plan using A* search
problemTrail3 = CoursePlanProblemTrail3(initial_state, course_info, max_units_per_semester, course_categories)
result = astar_tree_search(problemTrail3,min_remaining_units_heuristic)

if result != failure and result != cutoff:
    print("Course Plan:")
    for action, course in zip(path_actions(result), path_states(result)[1:]):
        print(f"Action: {action}, Course: {course}")
else:
    print("No valid course plan found.")
# Out:
# Course Plan:
# ...

# %% [markdown]
# Finishes in 7 semester but doestnot considers GE, GR, and science electives

# %% [markdown]
# ### Fourth Try (Output for  CoursePlanProblemTrail4 Problem Definition)

# %%
max_units_per_semester = 17
# Define the initial state, course info, and course categories
initial_state = {course: 'not_completed' for course in course_info_complete}
course_categories = {
    'Upper-Division Core': 30,
    'Lower-Division Core': 18,
    'Mathematics Requirements': 18,
    'Computer Science Electives': 15,
    'GE Requirement' : 24,
    'GR Requirement' : 3,
    'Science Elective' : 12,
}


problemTrail4 = CoursePlanProblemTrail4(initial_state, course_info_complete, max_units_per_semester, course_categories)
result = astar_tree_search(problemTrail4,min_remaining_units_heuristic_per_category)

if result != failure and result != cutoff:
  print("Course Plan:")
  for action, course in zip(path_actions(result), path_states(result)[1:]):
    print(f"Action: {action}, Course: {course['remaining_units']}")
else:
    print("No valid course plan found.")
# Out:
# Course Plan:
# Action: ('Take', 'CPSC120'), Course: {'Upper-Division Core': 3, 'Lower-Division Core': 0, 'Mathematics Requirements': -480, 'Computer Science Electives': -1438, 'GE Requirement': -1, 'GR Requirement': 0, 'Science Elective': -1}
# Action: ('Take', 'MATH170A'), Course: {'Upper-Division Core': 3, 'Lower-Division Core': 0, 'Mathematics Requirements': -480, 'Computer Science Electives': -1438, 'GE Requirement': -1, 'GR Requirement': 0, 'Science Elective': -1}
# Action: ('Take', 'CPSC499'), Course: {'Upper-Division Core': 3, 'Lower-Division Core': 0, 'Mathematics Requirements': -480, 'Computer Science Electives': -1438, 'GE Requirement': -1, 'GR Requirement': 0, 'Science Elective': -1}
# Action: ('Take', 'MATH125'), Course: {'Upper-Division Core': 3, 'Lower-Division Core': 0, 'Mathematics Requirements': -480, 'Computer Science Electives': -1438, 'GE Requirement': -1, 'GR Requirement': 0, 'Science Elective': -1}
# ...

# %% [markdown]
# ### Final Solution (Output for  CoursePlanProblem Problem Definition)

# %%
max_units_per_semester = 17
# Define the initial state, course info, and course categories
initial_state = {course: 'not_completed' for course in course_info_complete}
course_categories = {
    'Upper-Division Core': 30,
    'Lower-Division Core': 18,
    'Mathematics Requirements': 18,
    'Computer Science Electives': 15,
    'GE Requirement' : 24,
    'GR Requirement' : 3,
    'Science Elective' : 12,
}

# Find a course plan using A* search
problemTrail5 = CoursePlanProblem(initial_state, course_info_complete, max_units_per_semester, course_categories)
result = astar_tree_search(problemTrail5,min_remaining_units_heuristic_per_category)


if result != failure and result != cutoff:
    i = 1
    units_for_this_semester = 0
    print("\nCourse Plan:")
    current_sem_course = []
    for action, course in zip(path_actions(result), path_states(result)[1:]):

        if action[0] == 'Take':
            print("\nSemester: " + str(i))
            print(f"Action: {action} " + str(course_info_complete[action[1]].get("name")))
            units_for_this_semester += course_info_complete[action[1]].get("units")
            current_sem_course.append(action[1])
            print("Total units so far: " + str(units_for_this_semester))
            if units_for_this_semester > 15:
                units_for_this_semester = 0
        elif action[0] == 'Complete':
            units_for_this_semester = 0
            print("\nBy the end of the semester: " + str(i))
            i += 1
            # print("\ncourses taken", current_sem_course)
            for cors in current_sem_course:
                print(f"{action[0]} " + f"{cors} " + str(course_info_complete[cors].get("name")))
            current_sem_course = []
        #print(f"\nCourse Status: {course}")
else:
    print("\nNo valid course plan found.")
# Out:
# Course Plan:
#
# Semester: 1
# Action: ('Take', 'MATH125') Basic Calculus
# Total units so far: 4
#
# Semester: 1
# Action: ('Take', 'Science1') Science1 Placeholder
# Total units so far: 8
#
# Semester: 1
# Action: ('Take', 'GE10') GE10 Placeholder
# Total units so far: 12
#
# Semester: 1
# Action: ('Take', 'GE9') GE9 Placeholder
# Total units so far: 16
#
# By the end of the semester: 1
# Complete MATH125 Basic Calculus
# Complete Science1 Science1 Placeholder
# Complete GE10 GE10 Placeholder
# Complete GE9 GE9 Placeholder
#
# Semester: 2
# Action: ('Take', 'MATH150A') Calculus I
# Total units so far: 4
#
# Semester: 2
# Action: ('Take', 'Science3') Science3 Placeholder
# Total units so far: 8
#
# Semester: 2
# Action: ('Take', 'EGGN495') Professional Practice
# Total units so far: 10
#
# Semester: 2
# Action: ('Take', 'CPSC120') Introduction to Programming
# Total units so far: 13
#
# Semester: 2
# Action: ('Take', 'Science2') Science2 Placeholder
# Total units so far: 17
#
# ...

# %% [markdown]
# #### Comparing this with the CSUF CS roadmap shows us that:
# - the Astar search gives an output that satisfies all the
# requirment is a bit different from CSUF roadmap in terms of optimizing the total number of units
# - The heuristic Function could Probably be updated to better optimize the total number of units

# %% [markdown]
# ## Output: student in middle of the degree (starting from 3rd sem)

# %%
max_units_per_semester = 17
# Define the initial state, course info, and course categories
initial_state = {course: 'not_completed' for course in course_info_complete}
initial_state = {"CPSC120": "completed",
"CPSC121" : "completed",
"CPSC131" :"not_completed",
"CPSC223C/J/N/P/W/" :"not_completed",
"CPSC240" :"not_completed",
"CPSC253" :"completed",
"CPSC315" :"not_completed",
"CPSC323" :"not_completed",
"CPSC332" :"not_completed",
"CPSC335" :"not_completed",
"CPSC351" :"not_completed",
"CPSC362" :"not_completed",
"CPSC471" :"not_completed",
"CPSC481" :"not_completed",
"CPSC490" :"not_completed",
"CPSC491" :"not_completed",
"MATH125" :"not_completed",
"MATH150A" :"not_completed",
"MATH150B" :"not_completed",
"MATH170A" :"completed",
"MATH170B" :"completed",
"MATH338" :"not_completed",
"CPSC254" :"not_completed",
"CPSC301" :"not_completed",
"CPSC349" :"not_completed",
"CPSC352" :"not_completed",
"CPSC375" :"not_completed",
"CPSC386" :"not_completed",
"CPSC411" :"not_completed",
"CPSC411A" :"not_completed",
"CPSC431" :"not_completed",
"CPSC439" :"not_completed",
"CPSC440" :"not_completed",
"CPSC449" :"not_completed",
"CPSC454" :"not_completed",
"CPSC455" :"not_completed",
"CPSC456" :"not_completed",
"CPSC458" :"not_completed",
"CPSC459" :"not_completed",
"CPSC462" :"not_completed",
"CPSC463" :"not_completed",
"CPSC464" :"not_completed",
"CPSC466" :"not_completed",
"CPSC474" :"not_completed",
"CPSC479" :"not_completed",
"CPSC483" :"not_completed",
"CPSC484" :"not_completed",
"CPSC485" :"not_completed",
"CPSC486" :"not_completed",
"CPSC489" :"not_completed",
"CPSC499" :"completed",
"EGGN495" :"completed",
"GE1" :"completed",
"GE2" :"completed",
"GE3" :"not_completed",
"GE4" :"not_completed",
"GE5" :"not_completed",
"GE6" :"not_completed",
"GE7" :"not_completed",
"GE8" :"not_completed",
"GE9" :"not_completed",
"GE10" :"not_completed",
'GE11' :"completed",
"GE12" :"completed",
"GR1" :"not_completed",
"Science1" :"not_completed",
"Science2" :"not_completed",
"Science3" :"not_completed",
"Science4" :"not_completed",
"Science5" :"completed",}

course_categories = {
    'Upper-Division Core': 30,
    'Lower-Division Core': 9,
    'Mathematics Requirements': 12,
    'Computer Science Electives': 10,
    'GE Requirement' : 14,
    'GR Requirement' : 3,
    'Science Elective' : 10,
}
# Find a course plan using A* search
problemTrail5 = CoursePlanProblem(initial_state, course_info_complete, max_units_per_semester, course_categories, 3)
result = astar_tree_search(problemTrail5,min_remaining_units_heuristic_per_category)


if result != failure and result != cutoff:
    i = 3
    units_for_this_semester = 0
    print("\nCourse Plan:")
    current_sem_course = []
    for action, course in zip(path_actions(result), path_states(result)[1:]):

        if action[0] == 'Take':
            print("\nSemester: " + str(i))
            print(f"Action: {action} " + str(course_info_complete[action[1]].get("name")))
            units_for_this_semester += course_info_complete[action[1]].get("units")
            current_sem_course.append(action[1])
            print("Total units so far: " + str(units_for_this_semester))
            if units_for_this_semester > 15:
                units_for_this_semester = 0
        elif action[0] == 'Complete':
            units_for_this_semester = 0
            print("\nBy the end of the semester: " + str(i))
            i += 1
            # print("\ncourses taken", current_sem_course)
            for cors in current_sem_course:
                print(f"{action[0]} " + f"{cors} " + str(course_info_complete[cors].get("name")))
            current_sem_course = []
        #print(f"\nCourse Status: {course}")
else:
    print("\nNo valid course plan found.")
# Out:
# Course Plan:
#
# Semester: 3
# Action: ('Take', 'MATH125') Basic Calculus
# Total units so far: 4
#
# Semester: 3
# Action: ('Take', 'Science1') Science1 Placeholder
# Total units so far: 8
#
# Semester: 3
# Action: ('Take', 'GE10') GE10 Placeholder
# Total units so far: 12
#
# Semester: 3
# Action: ('Take', 'GE9') GE9 Placeholder
# Total units so far: 16
#
# By the end of the semester: 3
# Complete MATH125 Basic Calculus
# Complete Science1 Science1 Placeholder
# Complete GE10 GE10 Placeholder
# Complete GE9 GE9 Placeholder
#
# Semester: 4
# Action: ('Take', 'Science2') Science2 Placeholder
# Total units so far: 4
#
# Semester: 4
# Action: ('Take', 'Science3') Science3 Placeholder
# Total units so far: 8
#
# Semester: 4
# Action: ('Take', 'CPSC131') Data Structures
# Total units so far: 11
#
# Semester: 4
# Action: ('Take', 'MATH150A') Calculus I
# Total units so far: 15
#
# By the end of the semester: 4
# Complete Science2 Science2 Placeholder
# ...

# %% [markdown]
# ## Output: student is undergrad team member

# %%
max_units_per_semester = 17

# Define the initial state, course info, and course categories

initial_state = {course: 'not_completed' for course in course_info_complete}

initial_state = {"CPSC120": "completed",
"CPSC121" : "completed",
"CPSC131" : "completed",
"CPSC223C/J/N/P/W/" :"completed",
"CPSC240" :"completed",
"CPSC253" :"completed",
"CPSC315" :"completed",
"CPSC323" :"completed",
"CPSC332" :"completed",
"CPSC335" :"completed",
"CPSC351" :"completed",
"CPSC362" :"completed",
"CPSC471" :"completed",
"CPSC481" :"not_completed",
"CPSC490" :"completed",
"CPSC491" :"not_completed",
"MATH125" :"completed",
"MATH150A" :"completed",
"MATH150B" :"completed",
"MATH170A" :"completed",
"MATH170B" :"completed",
"MATH338" :"completed",
"CPSC254" :"not_completed",
"CPSC301" :"not_completed",
"CPSC349" :"not_completed",
"CPSC352" :"not_completed",
"CPSC375" :"completed",
"CPSC386" :"not_completed",
"CPSC411" :"not_completed",
"CPSC411A" :"not_completed",
"CPSC431" :"not_completed",
"CPSC439" :"not_completed",
"CPSC440" :"not_completed",
"CPSC449" :"not_completed",
"CPSC454" :"not_completed",
"CPSC455" :"not_completed",
"CPSC456" :"not_completed",
"CPSC458" :"not_completed",
"CPSC459" :"not_completed",
"CPSC462" :"completed",
"CPSC463" :"completed",
"CPSC464" :"not_completed",
"CPSC466" :"not_completed",
"CPSC474" :"not_completed",
"CPSC479" :"not_completed",
"CPSC483" :"not_completed",
"CPSC484" :"not_completed",
"CPSC485" :"not_completed",
"CPSC486" :"not_completed",
"CPSC489" :"not_completed",
"CPSC499" :"not_completed",
"EGGN495" :"not_completed",
"GE1" :"completed",
"GE2" :"completed",
"GE3" :"completed",
"GE4" :"completed",
"GE5" :"completed",
"GE6" :"completed",
"GE7" :"completed",
"GE8" :"completed",
"GE9" :"completed",
"GE10" :"completed",
'GE11' :"completed",
"GE12" :"completed",
"GR1" :"completed",
"Science1" :"completed",
"Science2" :"completed",
"Science3" :"completed",
"Science4" :"completed",
"Science5" :"completed",}

course_categories = {
    'Upper-Division Core': 6,
    'Lower-Division Core': 0,
    'Mathematics Requirements': 0,
    'Computer Science Electives': 9,
    'GE Requirement' : 0,
    'GR Requirement' : 0,
    'Science Elective' : 0,
}

# Find a course plan using A* search
problemTrail6 = CoursePlanProblem(initial_state, course_info_complete, max_units_per_semester, course_categories, 3)
result = astar_tree_search(problemTrail6,min_remaining_units_heuristic_per_category)


if result != failure and result != cutoff:
    i = 8
    units_for_this_semester = 0
    print("\nCourse Plan:")
    current_sem_course = []
    for action, course in zip(path_actions(result), path_states(result)[1:]):

        if action[0] == 'Take':
            print("\nSemester: " + str(i))
            print(f"Action: {action} " + str(course_info_complete[action[1]].get("name")))
            units_for_this_semester += course_info_complete[action[1]].get("units")
            current_sem_course.append(action[1])
            print("Total units so far: " + str(units_for_this_semester))
            if units_for_this_semester > 15:
                units_for_this_semester = 0
        elif action[0] == 'Complete':
            units_for_this_semester = 0
            print("\nBy the end of the semester: " + str(i))
            i += 1
            # print("\ncourses taken", current_sem_course)
            for cors in current_sem_course:
                print(f"{action[0]} " + f"{cors} " + str(course_info_complete[cors].get("name")))
            current_sem_course = []
        #print(f"\nCourse Status: {course}")
else:
    print("\nNo valid course plan found.")
# Out:
# Course Plan:
#
# Semester: 8
# Action: ('Take', 'CPSC481') Artificial Intelligence
# Total units so far: 3
#
# Semester: 8
# Action: ('Take', 'CPSC254') Software Development with Open Source Systems
# Total units so far: 6
#
# Semester: 8
# Action: ('Take', 'CPSC349') Web Front-End Engineering
# Total units so far: 9
#
# Semester: 8
# Action: ('Take', 'CPSC301') Programming Lab Practicum
# Total units so far: 11
#
# Semester: 8
# Action: ('Take', 'CPSC352') Cryptography
# Total units so far: 14
#
# Semester: 8
# Action: ('Take', 'CPSC491') Senior Capstone Project in Computer Science
# Total units so far: 17
#
# By the end of the semester: 8
# Complete CPSC481 Artificial Intelligence
# Complete CPSC254 Software Development with Open Source Systems
# Complete CPSC349 Web Front-End Engineering
# Complete CPSC301 Programming Lab Practicum
# Complete CPSC352 Cryptography
# Complete CPSC491 Senior Capstone Project in Computer Science

# %% [markdown]
# ## Output: if student has a Prefernece

# %%
max_units_per_semester = 17
# Define the initial state, course info, and course categories
initial_state = {course: 'not_completed' for course in course_info_complete}
course_categories = {
    'Upper-Division Core': 30,
    'Lower-Division Core': 18,
    'Mathematics Requirements': 18,
    'Computer Science Electives': 15,
    'GE Requirement' : 24,
    'GR Requirement' : 3,
    'Science Elective' : 12,
}

prefernce_list  = ["CPSC449","CPSC411A"]
# new heuristiv function that helps chose course in preference
def min_remaining_units_heuristic_with_preference(node, preference_list=prefernce_list):
    remaining_units = node.state.get('remaining_units', {})
    total_remaining = 0

    for category, units in remaining_units.items():
        if units >= 0:
            total_remaining += units

    # print(prefernce_list)
    for course, status in node.state.items():
        if course in preference_list and status in ['completed', 'in_progress']:
            # print(prefernce_list)
            total_remaining += course_info_complete[course].get('units',0)

    return total_remaining
# Find a course plan using A* search
problemPreference= CoursePlanProblem(initial_state, course_info_complete, max_units_per_semester, course_categories,1, prefernce_list)
result = astar_tree_search(problemPreference,min_remaining_units_heuristic_with_preference)


if result != failure and result != cutoff:
    i = 1
    units_for_this_semester = 0
    print("\nCourse Plan:")
    current_sem_course = []
    for action, course in zip(path_actions(result), path_states(result)[1:]):

        if action[0] == 'Take':
            print("\nSemester: " + str(i))
            print(f"Action: {action} " + str(course_info_complete[action[1]].get("name")))
            units_for_this_semester += course_info_complete[action[1]].get("units")
            current_sem_course.append(action[1])
            print("Total units so far: " + str(units_for_this_semester))
            if units_for_this_semester > 15:
                units_for_this_semester = 0
        elif action[0] == 'Complete':
            units_for_this_semester = 0
            print("\nBy the end of the semester: " + str(i))
            i += 1
            # print("\ncourses taken", current_sem_course)
            for cors in current_sem_course:
                print(f"{action[0]} " + f"{cors} " + str(course_info_complete[cors].get("name")))
            current_sem_course = []
        #print(f"\nCourse Status: {course}")
else:
    print("\nNo valid course plan found.")
# Out:
# Course Plan:
#
# Semester: 1
# Action: ('Take', 'MATH125') Basic Calculus
# Total units so far: 4
#
# Semester: 1
# Action: ('Take', 'Science1') Science1 Placeholder
# Total units so far: 8
#
# Semester: 1
# Action: ('Take', 'GE10') GE10 Placeholder
# Total units so far: 12
#
# Semester: 1
# Action: ('Take', 'GE9') GE9 Placeholder
# Total units so far: 16
#
# By the end of the semester: 1
# Complete MATH125 Basic Calculus
# Complete Science1 Science1 Placeholder
# Complete GE10 GE10 Placeholder
# Complete GE9 GE9 Placeholder
#
# Semester: 2
# Action: ('Take', 'MATH150A') Calculus I
# Total units so far: 4
#
# Semester: 2
# Action: ('Take', 'Science3') Science3 Placeholder
# Total units so far: 8
#
# Semester: 2
# Action: ('Take', 'EGGN495') Professional Practice
# Total units so far: 10
#
# Semester: 2
# Action: ('Take', 'CPSC120') Introduction to Programming
# Total units so far: 13
#
# Semester: 2
# Action: ('Take', 'Science2') Science2 Placeholder
# Total units so far: 17
#
# ...

# %% [markdown]
# # Summary
#
# *   Used the code from AIMA repo
# *   Defined three heuristics, one which calculates course in state 'not_completed', one which calculates 'Remaining units per category (lower division, upper division etc)', and one which promotes prefered subject if any
# *   Did plenty of approaches for problem definition and experimented with what works and what not, played around with state properties, class variable etc to understand what works
# *   Solution is able to give course plan in 8 semester fulfilling all the requirements in each category (including GE, GR and science electives)
# *   Solution for student in third semester, someone starting fresh, someone in the team and someone with a preference for electives
